# %%
import requests

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36',
}
url = "https://www.vmware.com/bin/vmware/getadvisorieslist?resourcePath=/content/vmware/vmware-published-sites/us/security/advisories"

# %%
json_data = requests.get(url, headers=headers).json()

# %%
json_data["data"]
# Out:
# [{'CVE': 'CVE-2021-22021',
#   'IssueDate': '2021-08-24',
#   'UpdatedOn': '2021-08-24',
#   'Severity': 'moderate',
#   'AdvisoryURL': '/security/advisories/VMSA-2021-0019.html',
#   'AdvisoryID': 'VMSA-2021-0019',
#   'Synopsis': 'VMware vRealize Log Insight updates address Cross Site Scripting (XSS) vulnerability (CVE-2021-22021)',
#   'CVSSv3Range': '6.5'},
#  {'CVE': 'CVE-2021-22022,  CVE-2021-22023, CVE-2021-22024, CVE-2021-22025, CVE-2021-22026, CVE-2021-22027',
#   'IssueDate': '2021-08-24',
#   'UpdatedOn': '2021-08-24',
#   'Severity': 'important',
#   'AdvisoryURL': '/security/advisories/VMSA-2021-0018.html',
#   'AdvisoryID': 'VMSA-2021-0018',
#   'Synopsis': 'VMware vRealize Operations updates address multiple security vulnerabilities (CVE-2021-22022,  CVE-2021-22023, CVE-2021-22024, CVE-2021-22025, CVE-2021-22026, CVE-2021-22027)',
#   'CVSSv3Range': '4.4 - 8.6'},
#  {'CVE': 'CVE-2021-22029',
#   'IssueDate': '2021-08-19',
#   'UpdatedOn': '2021-08-19',
#   'Severity': 'moderate',
#   'AdvisoryURL': '/security/advisories/VMSA-2021-0017.html',
#   'AdvisoryID': 'VMSA-2021-0017',
#   'Synopsis': 'VMware Workspace ONE UEM console patches address a denial of service vulnerability (CVE-2021-22029)',
#   'CVSSv3Range': '5.3'},
#  {'CVE': 'CVE-2021-22002, CVE-2021-22003',
#   'IssueDate': '2021-08-05',
#   'UpdatedOn': '2021-08-12',
#   'Severity': 'important',
#   'AdvisoryURL': '/security/advisories/VMSA-2021-0016.html',
#   'AdvisoryID': 'VMSA-2021-0016.1',
#   'Synopsis': 'VMware Workspace ONE Access, Identity Manager and vRealize Automation address multiple vulnerabilities (CVE-2021-22002, CVE-2021-22003)',
#   'CVSSv3Range': '3.7-8.6'},
#  {'CVE': 'CVE-2021-22000',
#   'IssueDate': '2021-07-13',
#   'UpdatedOn': '2021-07-13',
#   'Severity': 'moderate',
#   'AdvisoryURL': '/security/advisories/VMSA-2021-0015.html',
#   'AdvisoryID': 'VMSA-2021-0015',
#   'Synopsis': 'VMware ThinApp update addresses a DLL hijacking vulnerability (CVE-2021-22000)',
#   'CVSSv3Range': '6.8'},
#  {'CVE': 'CVE-2021-21994, CVE-2021-21995',
#   'IssueDate': '2021-07-13',
#   'UpdatedOn': '2021-08-24',
#   'Severity': 'important',
#   'AdvisoryURL': '/security/advisories/VMSA-2021-0014.html',
#   'AdvisoryID': 'VMSA-2021-0014.1',
#   'Synopsis': 'VMware ESXi updates address authentication and denial of service vulnerabilities (CVE-2021-21994, CVE-2021-21995)',
#   'CVSSv3Range': '5.3-7.0'},
#  {'CVE': 'CVE-2021-21999',
#   'IssueDate': '2021-06-22',
#   'UpdatedOn': '2021-06-22',
#   'Severity': 'important',
#   'AdvisoryURL': '/security/advisories/VMSA-2021-0013.html',
#   'AdvisoryID': 'VMSA-2021-0013',
#   'Synopsis': 'VMware Tools, VMRC and VMware App Volumes update addresses a local privilege escalation vulnerability (CVE-2021-21999)',
#   'CVSSv3Range': '7.8'},
#  {'CVE': 'CVE-2021-21998',
#   'IssueDate': '2021-06-22',
#   'UpdatedOn': '2021-06-22',
#   'Severity': 'critical',
#   'AdvisoryURL': '/security/advisories/VMSA-2021-0012.html',
#   'AdvisoryID': 'VMSA-2021-0012',
#   'Synopsis': 'VMware Carbon Black App Control update addresses authentication bypass (CVE-2021-21998)',
#   'CVSSv3Range': '9.4'},
#  {'CVE': 'CVE-2021-21997',
#   'IssueDate': '2021-06-17',
#   'UpdatedOn': '2021-06-17',
#   'Severity': 'low',
#   'AdvisoryURL': '/security/advisories/VMSA-2021-0011.html',
#   'AdvisoryID': 'VMSA-2021-0011',
#   'Synopsis': 'VMware Tools for Windows update addresses a denial-of-service vulnerability (CVE-2021-21997)',
#   'CVSSv3Range': '3.3'},
#  {'CVE': 'CVE-2021-21985, CVE-2021-21986',
#   'IssueDate': '2021-05-25',
#   'UpdatedOn': '2021-05-25',
#   'Severity': 'critical',
#   'AdvisoryURL': '/security/advisories/VMSA-2021-0010.html',
#   'AdvisoryID': 'VMSA-2021-0010',
#   'Synopsis': 'VMware vCenter Server updates address remote code execution and authentication vulnerabilities (CVE-2021-21985, CVE-2021-21986)',
#   'CVSSv3Range': '6.5-9.8'},
#  {'CVE': 'CVE-2021-21987, CVE-2021-21988, CVE-2021-21989',
#   'IssueDate': '2021-05-20',
#   'UpdatedOn': '2021-05-20',
#   'Severity': 'low',
#   'AdvisoryURL': '/security/advisories/VMSA-2021-0009.html',
#   'AdvisoryID': 'VMSA-2021-0009',
#   'Synopsis': 'VMware Workstation and Horizon Client for Windows updates address multiple security vulnerabilities (CVE-2021-21987, CVE-2021-21988, CVE-2021-21989)',
#   'CVSSv3Range': '3.2'},
#  {'CVE': 'CVE-2021-21990',
#   'IssueDate': '2021-05-11',
#   'UpdatedOn': '2021-05-11',
#   'Severity': 'low',
#   'AdvisoryURL': '/security/advisories/VMSA-2021-0008.html',
#   'AdvisoryID': 'VMSA-2021-0008',
#   'Synopsis': 'VMware Workspace ONE UEM console patches address a cross-site scripting vulnerability (CVE-2021-21990)',
#   'CVSSv3Range': '3.7'},
#  {'CVE': 'CVE-2021-21984',
#   'IssueDate': '2021-05-05',
#   'UpdatedOn': '2021-05-05',
#   'Severity': 'critical',
#   'AdvisoryURL': '/security/advisories/VMSA-2021-0007.html',
#   'AdvisoryID': 'VMSA-2021-0007',
#   'Synopsis': 'VMware vRealize Business for Cloud updates address a remote code execution vulnerability (CVE-2021-21984)',
#   'CVSSv3Range': '9.8'},
#  {'CVE': 'CVE-2021-21981',
#   'IssueDate': '2021-04-19',
#   'UpdatedOn': '2021-04-19',
#   'Severity': 'important',
#   'AdvisoryURL': '/security/advisories/VMSA-2021-0006.html',
#   'AdvisoryID': 'VMSA-2021-0006',
#   'Synopsis': 'VMware NSX-T updates address a privilege escalation vulnerability (CVE-2021-21981)',
#   'CVSSv3Range': '7.5'},
#  {'CVE': 'CVE-2021-21982',
#   'IssueDate': '2021-04-01',
#   'UpdatedOn': '2021-04-01',
#   'Severity': 'critical',
#   'AdvisoryURL': '/security/advisories/VMSA-2021-0005.html',
#   'AdvisoryID': 'VMSA-2021-0005',
#   'Synopsis': 'VMware Carbon Black Cloud Workload appliance update addresses incorrect URL handling vulnerability (CVE-2021-21982)',
#   'CVSSv3Range': '9.1'},
#  {'CVE': 'CVE-2021-21975, CVE-2021-21983',
#   'IssueDate': '2021-03-30',
#   'UpdatedOn': '2021-08-24',
#   'Severity': 'critical',
#   'AdvisoryURL': '/security/advisories/VMSA-2021-0004.html',
#   'AdvisoryID': 'VMSA-2021-0004.2',
#   'Synopsis': 'VMware vRealize Operations updates address Server Side Request Forgery and Arbitrary File Write vulnerabilities (CVE-2021-21975, CVE-2021-21983)',
#   'CVSSv3Range': '7.2 - 8.6'},
#  {'CVE': 'CVE-2021-21978',
#   'IssueDate': '2021-03-02',
#   'UpdatedOn': '2021-03-02',
#   'Severity': 'important',
#   'AdvisoryURL': '/security/advisories/VMSA-2021-0003.html',
#   'AdvisoryID': 'VMSA-2021-0003',
#   'Synopsis': 'VMware View Planner update addresses remote code execution vulnerability (CVE-2021-21978)',
#   'CVSSv3Range': '8.6'},
#  {'CVE': 'CVE-2021-21972, CVE-2021-21973, CVE-2021-21974',
#   'IssueDate': '2021-02-23',
#   'UpdatedOn': '2021-02-23',
#   'Severity': 'critical',
#   'AdvisoryURL': '/security/advisories/VMSA-2021-0002.html',
#   'AdvisoryID': 'VMSA-2021-0002',
#   'Synopsis': 'VMware ESXi and vCenter Server updates address multiple security vulnerabilities (CVE-2021-21972, CVE-2021-21973, CVE-2021-21974)',
#   'CVSSv3Range': '5.3-9.8'},
#  {'CVE': 'CVE-2021-21976',
#   'IssueDate': '2021-02-11',
#   'UpdatedOn': '2021-02-11',
#   'Severity': 'important',
#   'AdvisoryURL': '/security/advisories/VMSA-2021-0001.html',
#   'AdvisoryID': 'VMSA-2021-0001',
#   'Synopsis': 'vSphere Replication updates address a command injection vulnerability (CVE-2021-21976)',
#   'CVSSv3Range': '7.2'},
#  {'CVE': 'CVE-2020-3999',
#   'IssueDate': '2020-12-17',
#   'UpdatedOn': '2021-02-09',
#   'Severity': 'low',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0029.html',
#   'AdvisoryID': 'VMSA-2020-0029.1',
#   'Synopsis': 'VMware ESXi, Workstation, Fusion and Cloud Foundation updates address a denial of service vulnerability (CVE-2020-3999)',
#   'CVSSv3Range': '3.3'},
#  {'CVE': 'CVE-2020-4008',
#   'IssueDate': '2020-12-15',
#   'UpdatedOn': '2020-12-15',
#   'Severity': 'low',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0028.html',
#   'AdvisoryID': 'VMSA-2020-0028',
#   'Synopsis': 'VMware Carbon Black Cloud macOS Sensor installer updates address file overwrite issue (CVE-2020-4008)',
#   'CVSSv3Range': '3.6'},
#  {'CVE': 'CVE-2020-4006',
#   'IssueDate': '2020-11-23',
#   'UpdatedOn': '2020-12-03',
#   'Severity': 'important',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0027.html',
#   'AdvisoryID': 'VMSA-2020-0027.2',
#   'Synopsis': 'VMware Workspace One Access, Access Connector, Identity Manager, and Identity Manager Connector address command injection vulnerability',
#   'CVSSv3Range': '7.2'},
#  {'CVE': 'CVE-2020-4004, CVE-2020-4005',
#   'IssueDate': '2020-11-19',
#   'UpdatedOn': '2020-11-24',
#   'Severity': 'critical',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0026.html',
#   'AdvisoryID': 'VMSA-2020-0026.1',
#   'Synopsis': 'VMware ESXi, Workstation and Fusion updates address use-after-free and privilege escalation vulnerabilities (CVE-2020-4004, CVE-2020-4005)',
#   'CVSSv3Range': '8.8 - 9.3'},
#  {'CVE': 'CVE-2020-3984, CVE-2020-3985, CVE-2020-4000, CVE-2020-4001, CVE-2020-4002 ,CVE-2020-4003',
#   'IssueDate': '2020-11-18',
#   'UpdatedOn': '2020-11-18',
#   'Severity': 'important',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0025.html',
#   'AdvisoryID': 'VMSA-2020-0025',
#   'Synopsis': 'VMware SD-WAN Orchestrator updates address multiple security vulnerabilities (CVE-2020-3984, CVE-2020-3985, CVE-2020-4000, CVE-2020-4001, CVE-2020-4002 ,CVE-2020-4003)',
#   'CVSSv3Range': '6.3- 7.5'},
#  {'CVE': 'CVE-2020-3997, CVE-2020-3998',
#   'IssueDate': '2020-10-22',
#   'UpdatedOn': '2020-10-22',
#   'Severity': 'moderate',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0024.html',
#   'AdvisoryID': 'VMSA-2020-0024',
#   'Synopsis': 'VMware Horizon Server and VMware Horizon Client updates address multiple security vulnerabilities (CVE-2020-3997, CVE-2020-3998)',
#   'CVSSv3Range': '3.3 - 4.1'},
#  {'CVE': 'CVE-2020-3981, CVE-2020-3982, CVE-2020-3992, CVE-2020-3993, CVE-2020-3994, CVE-2020-3995',
#   'IssueDate': '2020-10-20',
#   'UpdatedOn': '2020-11-24',
#   'Severity': 'critical',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0023.html',
#   'AdvisoryID': 'VMSA-2020-0023.3',
#   'Synopsis': 'VMware ESXi, Workstation, Fusion and NSX-T updates address multiple security vulnerabilities (CVE-2020-3981, CVE-2020-3982, CVE-2020-3992, CVE-2020-3993, CVE-2020-3994, CVE-2020-3995)',
#   'CVSSv3Range': '5.9 - 9.8'},
#  {'CVE': 'CVE-2020-3991',
#   'IssueDate': '2020-10-15',
#   'UpdatedOn': '2020-10-15',
#   'Severity': 'moderate',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0022.html',
#   'AdvisoryID': 'VMSA-2020-0022',
#   'Synopsis': 'VMware Horizon Client update addresses a denial-of-service vulnerability (CVE-2020-3991)',
#   'CVSSv3Range': '5.9'},
#  {'CVE': 'CVE-2020-3977',
#   'IssueDate': '2020-09-22',
#   'UpdatedOn': '2020-09-22',
#   'Severity': 'moderate',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0021.html',
#   'AdvisoryID': 'VMSA-2020-0021',
#   'Synopsis': 'Horizon DaaS update addresses a broken authentication vulnerability (CVE-2020-3977)',
#   'CVSSv3Range': '6.3'},
#  {'CVE': 'CVE-2020-3980, CVE-2020-3986, CVE-2020-3987, CVE-2020-3988, CVE-2020-3989, CVE-2020-3990',
#   'IssueDate': '2020-09-14',
#   'UpdatedOn': '2020-11-19',
#   'Severity': 'moderate',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0020.html',
#   'AdvisoryID': 'VMSA-2020-0020.1',
#   'Synopsis': 'VMware Workstation, Fusion and Horizon Client updates address multiple security vulnerabilities (CVE-2020-3980, CVE-2020-3986, CVE-2020-3987, CVE-2020-3988, CVE-2020-3989, CVE-2020-3990)',
#   'CVSSv3Range': '3.8-6.7'},
#  {'CVE': 'CVE-2020-3975',
#   'IssueDate': '2020-08-20',
#   'UpdatedOn': '2020-08-20',
#   'Severity': 'moderate',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0019.html',
#   'AdvisoryID': 'VMSA-2020-0019',
#   'Synopsis': 'VMware App Volumes patches address Stored Cross-Site Scripting (XSS) vulnerability (CVE-2020-3975)',
#   'CVSSv3Range': '4.5'},
#  {'CVE': 'CVE-2020-3976',
#   'IssueDate': '2020-08-20',
#   'UpdatedOn': '2020-08-20',
#   'Severity': 'moderate',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0018.html',
#   'AdvisoryID': 'VMSA-2020-0018',
#   'Synopsis': 'VMware ESXi, vCenter Server, and Cloud Foundation updates address a partial denial of service vulnerability (CVE-2020-3976)',
#   'CVSSv3Range': '5.3'},
#  {'CVE': 'CVE-2020-3974',
#   'IssueDate': '2020-07-09',
#   'UpdatedOn': '2020-07-09',
#   'Severity': 'important',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0017.html',
#   'AdvisoryID': 'VMSA-2020-0017',
#   'Synopsis': 'VMware Fusion, VMware Remote Console and Horizon Client updates address a privilege escalation vulnerability (CVE-2020-3974)',
#   'CVSSv3Range': '7.8'},
#  {'CVE': 'CVE-2020-3973',
#   'IssueDate': '2020-07-07',
#   'UpdatedOn': '2020-07-07',
#   'Severity': 'important',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0016.html',
#   'AdvisoryID': 'VMSA-2020-0016',
#   'Synopsis': 'VMware SD-WAN by VeloCloud updates address SQL-injection vulnerability (CVE-2020-3973)',
#   'CVSSv3Range': '8.5'},
#  {'CVE': 'CVE-2020-3962, CVE-2020-3963, CVE-2020-3964, CVE-2020-3965, CVE-2020-3966, CVE-2020-3967, CVE-2020-3968, CVE-2020-3969, CVE-2020-3970, CVE-2020-3971',
#   'IssueDate': '2020-06-23',
#   'UpdatedOn': '2020-07-02',
#   'Severity': 'critical',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0015.html',
#   'AdvisoryID': 'VMSA-2020-0015.2',
#   'Synopsis': 'VMware Cloud Foundation, ESXi, Workstation, and Fusion updates address multiple security vulnerabilities (CVE-2020-3962, CVE-2020-3963, CVE-2020-3964, CVE-2020-3965, CVE-2020-3966, CVE-2020-3967, CVE-2020-3968, CVE-2020-3969, CVE-2020-3970, CVE-2020-3971)',
#   'CVSSv3Range': '4.0 - 9.3'},
#  {'CVE': 'CVE-2020-3972',
#   'IssueDate': '2020-06-18',
#   'UpdatedOn': '2020-06-18',
#   'Severity': 'low',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0014.html',
#   'AdvisoryID': 'VMSA-2020-0014',
#   'Synopsis': 'VMware Tools for macOS update addresses a denial-of-service vulnerability (CVE-2020-3972)',
#   'CVSSv3Range': '3.3'},
#  {'CVE': 'CVE-2020-3961',
#   'IssueDate': '2020-06-09',
#   'UpdatedOn': '2020-06-09',
#   'Severity': 'important',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0013.html',
#   'AdvisoryID': 'VMSA-2020-0013',
#   'Synopsis': 'VMware Horizon Client for Windows update addresses privilege escalation vulnerability (CVE-2020-3961)',
#   'CVSSv3Range': '8.4'},
#  {'CVE': 'CVE-2020-3960',
#   'IssueDate': '2020-06-09',
#   'UpdatedOn': '2020-06-09',
#   'Severity': 'important',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0012.html',
#   'AdvisoryID': 'VMSA-2020-0012',
#   'Synopsis': 'VMware ESXi, Workstation and Fusion updates address out-of-bounds read vulnerability (CVE-2020-3960)',
#   'CVSSv3Range': '7.1'},
#  {'CVE': 'CVE-2020-3957, CVE-2020-3958, CVE-2020-3959',
#   'IssueDate': '2020-05-28',
#   'UpdatedOn': '2020-07-09',
#   'Severity': 'important',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0011.html',
#   'AdvisoryID': 'VMSA-2020-0011.1',
#   'Synopsis': 'VMware ESXi, Workstation, Fusion, VMware Remote Console and Horizon Client updates address multiple security vulnerabilities (CVE-2020-3957, CVE-2020-3958, CVE-2020-3959)',
#   'CVSSv3Range': '3.3-7.3'},
#  {'CVE': 'CVE-2020-3956',
#   'IssueDate': '2020-05-19',
#   'UpdatedOn': '2020-05-19',
#   'Severity': 'important',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0010.html',
#   'AdvisoryID': 'VMSA-2020-0010',
#   'Synopsis': 'VMware Cloud Director updates address Code Injection Vulnerability (CVE-2020-3956)',
#   'CVSSv3Range': '8.8'},
#  {'CVE': 'CVE-2020-11651, CVE-2020-11652',
#   'IssueDate': '2020-05-08',
#   'UpdatedOn': '2020-05-15',
#   'Severity': 'critical',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0009.html',
#   'AdvisoryID': 'VMSA-2020-0009.1',
#   'Synopsis': 'vRealize Operations Application Remote Collector (ARC) addresses Authentication Bypass and Directory Traversal vulnerabilities (CVE-2020-11651, CVE-2020-11652)',
#   'CVSSv3Range': '7.5-10.0'},
#  {'CVE': 'CVE-2020-3955',
#   'IssueDate': '2020-04-28',
#   'UpdatedOn': '2020-04-28',
#   'Severity': 'important',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0008.html',
#   'AdvisoryID': 'VMSA-2020-0008',
#   'Synopsis': 'VMware ESXi patches address Stored Cross-Site Scripting (XSS) vulnerability (CVE-2020-3955)',
#   'CVSSv3Range': '8.3'},
#  {'CVE': 'CVE-2020-3953, CVE-2020-3954',
#   'IssueDate': '2020-04-14',
#   'UpdatedOn': '2020-06-24',
#   'Severity': 'important',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0007.html',
#   'AdvisoryID': 'VMSA-2020-0007.2',
#   'Synopsis': 'VMware vRealize Log Insight addresses Cross Site Scripting (XSS) and Open Redirect vulnerabilities (CVE-2020-3953, CVE-2020-3954)',
#   'CVSSv3Range': '6.1 - 8.4'},
#  {'CVE': 'CVE-2020-3952',
#   'IssueDate': '2020-04-09',
#   'UpdatedOn': '2020-04-16',
#   'Severity': 'critical',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0006.html',
#   'AdvisoryID': 'VMSA-2020-0006.1',
#   'Synopsis': 'VMware vCenter Server updates address sensitive information disclosure vulnerability in the VMware Directory Service (vmdir) (CVE-2020-3952)',
#   'CVSSv3Range': '10.0'},
#  {'CVE': 'CVE-2020-3950, CVE-2020-3951',
#   'IssueDate': '2020-03-17',
#   'UpdatedOn': '2020-03-24',
#   'Severity': 'important',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0005.html',
#   'AdvisoryID': 'VMSA-2020-0005.2',
#   'Synopsis': 'VMware Workstation, Fusion, VMware Remote Console and Horizon Client updates address privilege escalation and denial-of-service vulnerabilities (CVE-2020-3950, CVE-2020-3951)',
#   'CVSSv3Range': '3.2-7.3'},
#  {'CVE': 'CVE-2019-5543, CVE-2020-3947 , CVE-2020-3948',
#   'IssueDate': '2020-03-12',
#   'UpdatedOn': '2020-03-14',
#   'Severity': 'critical',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0004.html',
#   'AdvisoryID': 'VMSA-2020-0004.1',
#   'Synopsis': 'VMware Horizon Client, VMRC, VMware Workstation and Fusion updates address use-after-free and privilege escalation vulnerabilities (CVE-2019-5543, CVE-2020-3947, CVE-2020-3948)',
#   'CVSSv3Range': '7.3-9.3'},
#  {'CVE': 'CVE-2020-3943, CVE-2020-3944, CVE-2020-3945',
#   'IssueDate': '2020-02-18',
#   'UpdatedOn': '2020-02-18',
#   'Severity': 'critical',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0003.html',
#   'AdvisoryID': 'VMSA-2020-0003',
#   'Synopsis': 'vRealize Operations for Horizon Adapter updates address multiple security vulnerabilities (CVE-2020-3943, CVE-2020-3944, CVE-2020-3945)',
#   'CVSSv3Range': '5.3-9.0'},
#  {'CVE': 'CVE-2020-3941',
#   'IssueDate': '2020-01-14',
#   'UpdatedOn': '2020-01-14',
#   'Severity': 'important',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0002.html',
#   'AdvisoryID': 'VMSA-2020-0002',
#   'Synopsis': 'VMware Tools workaround addresses a local privilege escalation vulnerability (CVE-2020-3941)',
#   'CVSSv3Range': '7.8'},
#  {'CVE': 'CVE-2020-3940',
#   'IssueDate': '2020-01-09',
#   'UpdatedOn': '2020-01-09',
#   'Severity': 'moderate',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-0001.html',
#   'AdvisoryID': 'VMSA-2020-0001',
#   'Synopsis': 'VMware Workspace ONE SDK and dependent mobile application updates address sensitive information disclosure vulnerability (CVE-2020-3940)',
#   'CVSSv3Range': '6.8'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2019-0023.html',
#   'AdvisoryID': 'VMSA-2019-0023',
#   'Synopsis': 'VMware Workstation and Horizon View Agent updates address a DLL-hijacking issue (CVE-2019-5539)\r\n'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2019-0022.html',
#   'AdvisoryID': 'VMSA-2019-0022',
#   'Synopsis': 'VMware ESXi and Horizon DaaS updates address OpenSLP remote code execution vulnerability (CVE-2019-5544)'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2019-0021.html',
#   'AdvisoryID': 'VMSA-2019-0021',
#   'Synopsis': 'VMware Workstation and Fusion updates address multiple security vulnerabilities (CVE-2019-5540, CVE-2019-5541, CVE-2019-5542)'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2019-0020.html',
#   'AdvisoryID': 'VMSA-2019-0020',
#   'Synopsis': 'VMware ESXi, Workstation, and Fusion patches provide Hypervisor-Specific Mitigations for Speculative-Execution Vulnerabilities (CVE-2018-12207, CVE-2019-11135)'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2019-0019.html',
#   'AdvisoryID': 'VMSA-2019-0019',
#   'Synopsis': 'VMware ESXi, Workstation and Fusion updates address a denial-of-service vulnerability (CVE-2019-5536)'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2019-0018.html',
#   'AdvisoryID': 'VMSA-2019-0018',
#   'Synopsis': 'VMware vCenter Server Appliance updates address sensitive information disclosure vulnerability in backup and restore functions (CVE-2019-5537, CVE-2019-5538)'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2019-0017.html',
#   'AdvisoryID': 'VMSA-2019-0017',
#   'Synopsis': 'VMware SD-WAN by VeloCloud update addresses information disclosure vulnerability (CVE-2019-5533)'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2019-0016.html',
#   'AdvisoryID': 'VMSA-2019-0016',
#   'Synopsis': 'VMware Cloud Foundation and VMware Harbor Container Registry for PCF address broken access control vulnerability (CVE-2019-16919)'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2019-0015.html',
#   'AdvisoryID': 'VMSA-2019-0015',
#   'Synopsis': 'VMware Cloud Foundation and VMware Harbor Container Registry for PCF address remote escalation of privilege vulnerability (CVE-2019-16097)'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2019-0014.html',
#   'AdvisoryID': 'VMSA-2019-0014.1',
#   'Synopsis': 'VMware ESXi, Workstation, Fusion, VMRC and Horizon Client updates address use-after-free and denial of service vulnerabilities. (CVE-2019-5527, CVE-2019-5535)'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2019-0013.html',
#   'AdvisoryID': 'VMSA-2019-0013.1',
#   'Synopsis': 'VMware ESXi and vCenter Server updates address command injection and information disclosure vulnerabilities. (CVE-2017-16544, CVE-2019-5531, CVE-2019-5532, CVE-2019-5534)'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2019-0012.html',
#   'AdvisoryID': 'VMSA-2019-0012',
#   'Synopsis': 'VMware ESXi, Workstation and Fusion updates address out-of-bounds read/write vulnerabilities (CVE-2019-5521, CVE-2019-5684)\r\n'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2019-0011.html',
#   'AdvisoryID': 'VMSA-2019-0011.1',
#   'Synopsis': 'ESXi patches address partial denial of service vulnerability in hostd process (CVE-2019-5528)'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2019-0010.html',
#   'AdvisoryID': 'VMSA-2019-0010.3',
#   'Synopsis': 'VMware product updates address Linux kernel vulnerabilities in TCP Selective Acknowledgement (SACK) (CVE-2019-11477, CVE-2019-11478)'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2019-0009.html',
#   'AdvisoryID': 'VMSA-2019-0009',
#   'Synopsis': 'VMware Tools and Workstation updates address out of bounds read and use-after-free vulnerabilities. (CVE-2019-5522, CVE-2019-5525)'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2019-0008.html',
#   'AdvisoryID': 'VMSA-2019-0008.2',
#   'Synopsis': 'VMware product updates enable Hypervisor-Specific Mitigations, Hypervisor-Assisted Guest Mitigations, and Operating System-Specific Mitigations for Microarchitectural Data Sampling (MDS) Vulnerabilities (CVE-2018-12126, CVE-2018-12127, CVE-2018-12130, and CVE-2019-11091)'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2019-0007.html',
#   'AdvisoryID': 'VMSA-2019-0007',
#   'Synopsis': 'VMware Workstation update addresses a DLL-hijacking issue (CVE-2019-5526)'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2019-0006.html',
#   'AdvisoryID': 'VMSA-2019-0006',
#   'Synopsis': 'VMware ESXi, Workstation and Fusion updates address multiple out-of-bounds read vulnerabilities'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2019-0005.html',
#   'AdvisoryID': 'VMSA-2019-0005.1',
#   'Synopsis': 'VMware ESXi, Workstation and Fusion updates address multiple security issues.\r\n'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2019-0004.html',
#   'AdvisoryID': 'VMSA-2019-0004',
#   'Synopsis': 'VMware vCloud Director for Service Providers update resolves a Remote Session Hijack vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2019-0003.html',
#   'AdvisoryID': 'VMSA-2019-0003',
#   'Synopsis': 'VMware Horizon update addresses Connection Server information disclosure vulnerability.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2019-0002.html',
#   'AdvisoryID': 'VMSA-2019-0002',
#   'Synopsis': 'VMware Workstation update addresses elevation of privilege issues.\r\n'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2019-0001.html',
#   'AdvisoryID': 'VMSA-2019-0001.3',
#   'Synopsis': 'VMware product updates resolve mishandled file descriptor vulnerability in runc container runtime.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0031.html',
#   'AdvisoryID': 'VMSA-2018-0031',
#   'Synopsis': 'vRealize Operations updates address a local privilege escalation vulnerability\r\n'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0030.html',
#   'AdvisoryID': 'VMSA-2018-0030',
#   'Synopsis': 'VMware Workstation and Fusion updates address an integer overflow issue.\r\n'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0029.html',
#   'AdvisoryID': 'VMSA-2018-0029',
#   'Synopsis': 'vSphere Data Protection (VDP) updates address multiple security issues.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0028.html',
#   'AdvisoryID': 'VMSA-2018-0028',
#   'Synopsis': 'VMware vRealize Log Insight updates address an authorization bypass vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0027.html',
#   'AdvisoryID': 'VMSA-2018-0027',
#   'Synopsis': 'VMware ESXi, Workstation, and Fusion updates address uninitialized stack memory usage\r\n'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0026.html',
#   'AdvisoryID': 'VMSA-2018-0026',
#   'Synopsis': 'VMware ESXi, Workstation, and Fusion updates address an out-of-bounds read vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0025.html',
#   'AdvisoryID': 'VMSA-2018-0025',
#   'Synopsis': 'VMware ESXi, Workstation, and Fusion workarounds address a denial-of-service vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0024.html',
#   'AdvisoryID': 'VMSA-2018-0024.1',
#   'Synopsis': 'VMware Workspace ONE Unified Endpoint Management Console (AirWatch Console) update resolves SAML authentication bypass vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0023.html',
#   'AdvisoryID': 'VMSA-2018-0023',
#   'Synopsis': 'AirWatch Agent and VMware Content Locker updates resolve data protection vulnerabilities'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0022.html',
#   'AdvisoryID': 'VMSA-2018-0022',
#   'Synopsis': 'VMware Workstation and Fusion updates address an out-of-bounds write issue'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0021.html',
#   'AdvisoryID': 'VMSA-2018-0021.2',
#   'Synopsis': 'Operating System-Specific Mitigations address L1 Terminal Fault - OS vulnerability in VMware Virtual Appliances.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0020.html',
#   'AdvisoryID': 'VMSA-2018-0020',
#   'Synopsis': 'VMware vSphere, Workstation, and Fusion updates enable Hypervisor-Specific Mitigations for L1 Terminal Fault - VMM vulnerability.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0019.html',
#   'AdvisoryID': 'VMSA-2018-0019.1',
#   'Synopsis': 'Horizon 6, 7, and Horizon Client for Windows updates address an out-of-bounds read vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0018.html',
#   'AdvisoryID': 'VMSA-2018-0018',
#   'Synopsis': 'VMware Horizon View Agent, VMware ESXi, Workstation, and Fusion updates resolve multiple security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0017.html',
#   'AdvisoryID': 'VMSA-2018-0017.4',
#   'Synopsis': 'VMware Tools update addresses an out-of-bounds read vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0016.html',
#   'AdvisoryID': 'VMSA-2018-0016',
#   'Synopsis': 'VMware ESXi, Workstation, and Fusion updates address multiple out-of-bounds read vulnerabilities'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0015.html',
#   'AdvisoryID': 'VMSA-2018-0015.1',
#   'Synopsis': 'VMware AirWatch Agent updates resolve remote code execution vulnerability.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0014.html',
#   'AdvisoryID': 'VMSA-2018-0014',
#   'Synopsis': 'VMware Horizon Client update addresses a privilege escalation vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0012.html',
#   'AdvisoryID': 'VMSA-2018-0012.1',
#   'Synopsis': 'VMware vSphere, Workstation and Fusion updates enable Hypervisor-Assisted Guest Mitigations for Speculative Store Bypass issue.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0013.html',
#   'AdvisoryID': 'VMSA-2018-0013',
#   'Synopsis': 'VMware Workstation and Fusion updates address signature bypass and multiple denial-of-service vulnerabilities'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0011.html',
#   'AdvisoryID': 'VMSA-2018-0011.1',
#   'Synopsis': 'Unauthenticated Command Injection vulnerability in VMware SD-WAN by VeloCloud'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0010.html',
#   'AdvisoryID': 'VMSA-2018-0010',
#   'Synopsis': 'Horizon DaaS update addresses a broken authentication issue'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0009.html',
#   'AdvisoryID': 'VMSA-2018-0009',
#   'Synopsis': 'vRealize Automation updates address multiple security issues. '},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0008.html',
#   'AdvisoryID': 'VMSA-2018-0008',
#   'Synopsis': 'Workstation and Fusion updates address a denial-of-service vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0007.html',
#   'AdvisoryID': 'VMSA-2018-0007.6',
#   'Synopsis': 'VMware Virtual Appliance updates address side-channel analysis due to speculative execution'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0006.html',
#   'AdvisoryID': 'VMSA-2018-0006',
#   'Synopsis': 'vRealize Automation, vSphere Integrated Containers, and AirWatch Console updates address multiple security vulnerabilities'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0005.html',
#   'AdvisoryID': 'VMSA-2018-0005',
#   'Synopsis': 'VMware Workstation, and Fusion updates resolve use-after-free and integer-overflow vulnerabilities'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0004.html',
#   'AdvisoryID': 'VMSA-2018-0004.3',
#   'Synopsis': 'VMware vSphere, Workstation and Fusion updates add Hypervisor-Assisted Guest Remediation for speculative execution issue'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0003.html',
#   'AdvisoryID': 'VMSA-2018-0003',
#   'Synopsis': 'vRealize Operations for Horizon, vRealize Operations for Published Applications,  Workstation, Horizon View Client and Tools updates resolve multiple security vulnerabilities'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0002.html',
#   'AdvisoryID': 'VMSA-2018-0002.3',
#   'Synopsis': 'VMware ESXi, Workstation and Fusion updates address side-channel analysis due to speculative execution.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2018-0001.html',
#   'AdvisoryID': 'VMSA-2018-0001',
#   'Synopsis': 'vSphere Data Protection (VDP) updates address multiple security issues.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2017-0021.html',
#   'AdvisoryID': 'VMSA-2017-0021',
#   'Synopsis': 'VMware ESXi, vCenter Server Appliance, Workstation and Fusion updates address multiple security vulnerabilities'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2017-0020.html',
#   'AdvisoryID': 'VMSA-2017-0020',
#   'Synopsis': 'VMware AirWatch Console updates address Broken Access Control vulnerability.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2017-0019.html',
#   'AdvisoryID': 'VMSA-2017-0019',
#   'Synopsis': 'NSX for vSphere update addresses NSX Edge Cross-Site Scripting (XSS) issue.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2017-0018.html',
#   'AdvisoryID': 'VMSA-2017-0018.1',
#   'Synopsis': 'VMware Workstation, Fusion and Horizon View Client updates resolve multiple security vulnerabilities'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2017-0017.html',
#   'AdvisoryID': 'VMSA-2017-0017',
#   'Synopsis': 'VMware vCenter Server update resolves LDAP DoS, SSRF and CRLF injection issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2017-0016.html',
#   'AdvisoryID': 'VMSA-2017-0016',
#   'Synopsis': 'VMware AirWatch Console and Launcher for Android updates resolve multiple vulnerabilities.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2017-0015.html',
#   'AdvisoryID': 'VMSA-2017-0015.2',
#   'Synopsis': 'VMware ESXi, vCenter Server, Fusion and Workstation updates resolve multiple security vulnerabilities'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2017-0014.html',
#   'AdvisoryID': 'VMSA-2017-0014',
#   'Synopsis': 'VMware NSX-V Edge updates address OSPF Protocol LSA DoS'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2017-0012.html',
#   'AdvisoryID': 'VMSA-2017-0012',
#   'Synopsis': 'VMware VIX API VM Direct Access Function security issue'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2017-0013.html',
#   'AdvisoryID': 'VMSA-2017-0013',
#   'Synopsis': 'VMware vCenter Server and Tools updates resolve multiple security vulnerabilities'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2017-0011.html',
#   'AdvisoryID': 'VMSA-2017-0011',
#   'Synopsis': 'Horizon View Client update addresses a command injection vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2017-0010.html',
#   'AdvisoryID': 'VMSA-2017-0010',
#   'Synopsis': 'vSphere Data Protection (VDP) updates address multiple security issues.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2017-0009.html',
#   'AdvisoryID': 'VMSA-2017-0009',
#   'Synopsis': 'VMware Workstation update addresses multiple security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2017-0008.html',
#   'AdvisoryID': 'VMSA-2017-0008.2',
#   'Synopsis': 'VMware Unified Access Gateway, Horizon View and Workstation updates resolve multiple security vulnerabilities'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2017-0007.html',
#   'AdvisoryID': 'VMSA-2017-0007',
#   'Synopsis': 'VMware vCenter Server updates resolve a remote code execution vulnerability via BlazeDS'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2017-0006.html',
#   'AdvisoryID': 'VMSA-2017-0006',
#   'Synopsis': 'VMware ESXi, Workstation and Fusion updates address critical and moderate security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2017-0005.html',
#   'AdvisoryID': 'VMSA-2017-0005',
#   'Synopsis': 'VMware Workstation and Fusion updates address out-of-bounds memory access vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2017-0004.html',
#   'AdvisoryID': 'VMSA-2017-0004.7',
#   'Synopsis': 'VMware product updates resolve remote code execution vulnerability via Apache Struts 2'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2017-0003.html',
#   'AdvisoryID': 'VMSA-2017-0003',
#   'Synopsis': 'VMware product updates address multiple important security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2017-0002.html',
#   'AdvisoryID': 'VMSA-2017-0002',
#   'Synopsis': 'Horizon DaaS update addresses an insecure data validation issue'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2017-0001.html',
#   'AdvisoryID': 'VMSA-2017-0001',
#   'Synopsis': 'AirWatch updates address bypass of root detection and local container encryption'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2016-0024.html',
#   'AdvisoryID': 'VMSA-2016-0024.1',
#   'Synopsis': 'vSphere Data Protection (VDP) update addresses SSH key-based authentication issue'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2016-0023.html',
#   'AdvisoryID': 'VMSA-2016-0023',
#   'Synopsis': 'VMware ESXi updates address a cross-site scripting issue'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2016-0022.html',
#   'AdvisoryID': 'VMSA-2016-0022',
#   'Synopsis': 'VMware product updates address information disclosure vulnerabilities\r\n'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2016-0021.html',
#   'AdvisoryID': 'VMSA-2016-0021',
#   'Synopsis': 'VMware product updates address partial information disclosure vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2016-0020.html',
#   'AdvisoryID': 'VMSA-2016-0020',
#   'Synopsis': 'vRealize Operations update addresses REST API deserialization vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2016-0019.html',
#   'AdvisoryID': 'VMSA-2016-0019',
#   'Synopsis': 'VMware Workstation and Fusion updates address critical out-of-bounds memory access vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2016-0018.html',
#   'AdvisoryID': 'VMSA-2016-0018.3',
#   'Synopsis': 'VMware product updates address local privilege escalation vulnerability in Linux kernel'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2016-0017.html',
#   'AdvisoryID': 'VMSA-2016-0017',
#   'Synopsis': 'VMware product updates address multiple information disclosure issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2016-0016.html',
#   'AdvisoryID': 'VMSA-2016-0016.1',
#   'Synopsis': 'vRealize Operations (vROps) updates address privilege escalation vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2016-0015.html',
#   'AdvisoryID': 'VMSA-2016-0015',
#   'Synopsis': 'VMware Horizon View updates address directory traversal vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2016-0014.html',
#   'AdvisoryID': 'VMSA-2016-0014.1',
#   'Synopsis': 'VMware ESXi, Workstation, Fusion, and Tools updates address multiple security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2016-0013.html',
#   'AdvisoryID': 'VMSA-2016-0013',
#   'Synopsis': 'VMware Identity Manager and vRealize Automation updates address multiple security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2016-0012.html',
#   'AdvisoryID': 'VMSA-2016-0012',
#   'Synopsis': 'VMware Photon OS OVA default public ssh key'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2016-0011.html',
#   'AdvisoryID': 'VMSA-2016-0011',
#   'Synopsis': 'vRealize Log Insight update addresses directory traversal vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2016-0010.html',
#   'AdvisoryID': 'VMSA-2016-0010.1',
#   'Synopsis': 'VMware product updates address multiple important security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2016-0009.html',
#   'AdvisoryID': 'VMSA-2016-0009',
#   'Synopsis': 'VMware vCenter Server updates address an important reflected cross-site scripting issue'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2016-0008.html',
#   'AdvisoryID': 'VMSA-2016-0008',
#   'Synopsis': 'VMware vRealize Log Insight addresses important and moderate security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2016-0007.html',
#   'AdvisoryID': 'VMSA-2016-0007.2',
#   'Synopsis': 'VMware NSX and vCNS product updates address a critical information disclosure vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2016-0006.html',
#   'AdvisoryID': 'VMSA-2016-0006',
#   'Synopsis': 'VMware vCenter Server updates address an important cross-site scripting issue'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2016-0005.html',
#   'AdvisoryID': 'VMSA-2016-0005.5',
#   'Synopsis': 'VMware product updates address critical and important security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2016-0004.html',
#   'AdvisoryID': 'VMSA-2016-0004',
#   'Synopsis': 'VMware product updates address a critical security issue in the VMware Client Integration Plugin'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2016-0003.html',
#   'AdvisoryID': 'VMSA-2016-0003',
#   'Synopsis': 'VMware vRealize Automation and vRealize Business Advanced and Enterprise address Cross-Site Scripting (XSS) issues.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2016-0002.html',
#   'AdvisoryID': 'VMSA-2016-0002.1',
#   'Synopsis': 'VMware product updates address a critical glibc security vulnerability.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2016-0001.html',
#   'AdvisoryID': 'VMSA-2016-0001',
#   'Synopsis': 'VMware ESXi, Fusion, Player, and Workstation updates address important guest privilege escalation vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2015-0009.html',
#   'AdvisoryID': 'VMSA-2015-0009.5',
#   'Synopsis': 'VMware vCenter Server updates address an important reflected cross-site scripting issue'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2015-0008.html',
#   'AdvisoryID': 'VMSA-2015-0008.2',
#   'Synopsis': 'VMware product updates address information disclosure issue.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2015-0007.html',
#   'AdvisoryID': 'VMSA-2015-0007.7',
#   'Synopsis': 'VMware vCenter and ESXi updates address critical security issues.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2015-0006.html',
#   'AdvisoryID': 'VMSA-2015-0006.1',
#   'Synopsis': 'VMware vCenter Server updates address a LDAP certificate validation issue'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2015-0005.html',
#   'AdvisoryID': 'VMSA-2015-0005',
#   'Synopsis': ' VMware Workstation, Player and Horizon View Client for Windows updates address a host privilege escalation vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2015-0004.html',
#   'AdvisoryID': 'VMSA-2015-0004',
#   'Synopsis': 'VMware Workstation, Fusion and Horizon View Client updates address critical security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2015-0003.html',
#   'AdvisoryID': 'VMSA-2015-0003.14',
#   'Synopsis': 'VMware product updates address critical information disclosure issue in JRE.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2015-0002.html',
#   'AdvisoryID': 'VMSA-2015-0002',
#   'Synopsis': 'VMware vSphere Data Protection product update addresses a certificate validation vulnerability.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2015-0001.html',
#   'AdvisoryID': 'VMSA-2015-0001.2',
#   'Synopsis': 'VMware vCenter Server, ESXi, Workstation, Player, and Fusion updates address security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2014-0014.html',
#   'AdvisoryID': 'VMSA-2014-0014',
#   'Synopsis': 'AirWatch by VMware product update addresses information disclosure vulnerabilities'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2014-0013.html',
#   'AdvisoryID': 'VMSA-2014-0013',
#   'Synopsis': 'VMware vCloud Automation Center product updates address a critical remote privilege escalation vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2014-0012.html',
#   'AdvisoryID': 'VMSA-2014-0012.1',
#   'Synopsis': 'VMware vSphere product updates address security vulnerabilities'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2014-0011.html',
#   'AdvisoryID': 'VMSA-2014-0011',
#   'Synopsis': 'VMware vSphere Data Protection product update addresses a critical information disclosure vulnerability.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2014-0010.html',
#   'AdvisoryID': 'VMSA-2014-0010.13',
#   'Synopsis': 'VMware product updates address critical Bash security vulnerabilities'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2014-0009.html',
#   'AdvisoryID': 'VMSA-2014-0009',
#   'Synopsis': 'VMware NSX and vCNS product updates address a critical information disclosure vulnerability.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2014-0008.html',
#   'AdvisoryID': 'VMSA-2014-0008.2',
#   'Synopsis': 'VMware vSphere product updates to third party libraries'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2014-0007.html',
#   'AdvisoryID': 'VMSA-2014-0007.2',
#   'Synopsis': 'VMware product updates address security vulnerabilities in Apache Struts library'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2014-0006.html',
#   'AdvisoryID': 'VMSA-2014-0006.11',
#   'Synopsis': 'VMware product updates address OpenSSL security vulnerabilities'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2014-0005.html',
#   'AdvisoryID': 'VMSA-2014-0005',
#   'Synopsis': 'VMware Workstation, Player, Fusion, and ESXi patches address a guest privilege escalation'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2014-0004.html',
#   'AdvisoryID': 'VMSA-2014-0004.7',
#   'Synopsis': 'VMware product updates address OpenSSL security vulnerabilities'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2014-0003.html',
#   'AdvisoryID': 'VMSA-2014-0003',
#   'Synopsis': 'VMware vSphere Client updates address security vulnerabilities'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2014-0002.html',
#   'AdvisoryID': 'VMSA-2014-0002.4',
#   'Synopsis': 'VMware vSphere updates to third party libraries'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2014-0001.html',
#   'AdvisoryID': 'VMSA-2014-0001',
#   'Synopsis': 'VMware Workstation, Player, Fusion, ESXi, ESX and vCloud Director address several security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2013-0016.html',
#   'AdvisoryID': 'VMSA-2013-0016',
#   'Synopsis': 'VMware ESXi and ESX unauthorized file access through vCenter Server and ESX'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2013-0015.html',
#   'AdvisoryID': 'VMSA-2013-0015',
#   'Synopsis': 'VMware ESX updates to third party libraries'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2013-0014.html',
#   'AdvisoryID': 'VMSA-2013-0014',
#   'Synopsis': 'VMware Workstation, Fusion, ESXi and ESX patches address a guest privilege escalation'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2013-0013.html',
#   'AdvisoryID': 'VMSA-2013-0013',
#   'Synopsis': 'VMware Workstation host privilege escalation vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2013-0012.html',
#   'AdvisoryID': 'VMSA-2013-0012.1',
#   'Synopsis': 'VMware vSphere updates address multiple vulnerabilities'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2013-0011.html',
#   'AdvisoryID': 'VMSA-2013-0011',
#   'Synopsis': 'VMware ESXi and ESX address an NFC Protocol Unhandled Exception'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2013-0010.html',
#   'AdvisoryID': 'VMSA-2013-0010',
#   'Synopsis': 'VMware Workstation host privilege escalation vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2013-0009.html',
#   'AdvisoryID': 'VMSA-2013-0009.3',
#   'Synopsis': 'VMware vSphere, ESX and ESXi updates to third party libraries'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2013-0008.html',
#   'AdvisoryID': 'VMSA-2013-0008',
#   'Synopsis': 'VMware vCenter Chargeback Manager Remote Code Execution'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2013-0007.html',
#   'AdvisoryID': 'VMSA-2013-0007.1',
#   'Synopsis': 'VMware ESX patch address security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2013-0006.html',
#   'AdvisoryID': 'VMSA-2013-0006.1',
#   'Synopsis': 'VMware security updates for vCenter Server'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2013-0005.html',
#   'AdvisoryID': 'VMSA-2013-0005',
#   'Synopsis': 'VMware vFabric Postgres security updates'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2013-0004.html',
#   'AdvisoryID': 'VMSA-2013-0004.3',
#   'Synopsis': 'VMware ESXi and ESX security update for third party library'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2013-0003.html',
#   'AdvisoryID': 'VMSA-2013-0003',
#   'Synopsis': 'VMware vCenter Server, ESXi and ESX address an NFC Protocol memory corruption and third party library security issues.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2013-0002.html',
#   'AdvisoryID': 'VMSA-2013-0002.1',
#   'Synopsis': 'VMware ESX, Workstation, Fusion, and View VMCI privilege escalation vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2013-0001.html',
#   'AdvisoryID': 'VMSA-2013-0001.5',
#   'Synopsis': 'VMware vSphere security updates for the authentication service and third party libraries'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2012-0018.html',
#   'AdvisoryID': 'VMSA-2012-0018.2',
#   'Synopsis': 'VMware security updates for vCSA, vCenter Server, and ESXi'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2012-0017.html',
#   'AdvisoryID': 'VMSA-2012-0017',
#   'Synopsis': 'VMware View Server directory traversal'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2012-0016.html',
#   'AdvisoryID': 'VMSA-2012-0016',
#   'Synopsis': 'VMware security updates for vSphere API and ESX Service Console'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2012-0015.html',
#   'AdvisoryID': 'VMSA-2012-0015',
#   'Synopsis': 'VMware Hosted Products and OVF Tool address security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2012-0014.html',
#   'AdvisoryID': 'VMSA-2012-0014',
#   'Synopsis': 'VMware vCenter Operations, CapacityIQ, and Movie Decoder security updates'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2012-0013.html',
#   'AdvisoryID': 'VMSA-2012-0013.2',
#   'Synopsis': 'VMware vSphere and vCOps updates to third party libraries'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2012-0012.html',
#   'AdvisoryID': 'VMSA-2012-0012.2',
#   'Synopsis': 'VMware ESXi update to third party library'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2012-0011.html',
#   'AdvisoryID': 'VMSA-2012-0011',
# ...
#  {'AdvisoryURL': '/security/advisories/VMSA-2012-0007.html',
#   'AdvisoryID': 'VMSA-2012-0007.1',
#   'Synopsis': 'VMware hosted products and ESXi/ESX patches address privilege escalation'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2012-0006.html',
#   'AdvisoryID': 'VMSA-2012-0006.2',
#   'Synopsis': 'VMware ESXi and ESX address several security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2012-0004.html',
#   'AdvisoryID': 'VMSA-2012-0004',
#   'Synopsis': 'VMware View privilege escalation and cross-site scripting'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2012-0005.html',
#   'AdvisoryID': 'VMSA-2012-0005.4',
#   'Synopsis': 'VMware vCenter Server, Orchestrator, Update Manager, vShield, vSphere Client, ESXi and ESX address several security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2012-0002.html',
#   'AdvisoryID': 'VMSA-2012-0002',
#   'Synopsis': 'VMware vCenter Chargeback Manager Information Leak and Denial of Service'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2012-0003.html',
#   'AdvisoryID': 'VMSA-2012-0003.1',
#   'Synopsis': 'VMware VirtualCenter Update and ESX 3.5 patch update JRE'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2012-0001.html',
#   'AdvisoryID': 'VMSA-2012-0001.2',
#   'Synopsis': 'VMware ESXi and ESX updates to third party library and ESX Service Console'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2011-0014.html',
#   'AdvisoryID': 'VMSA-2011-0014',
#   'Synopsis': 'VMware vCenter Update Manager fix for Jetty Web server addresses directory traversal vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2011-0013.html',
#   'AdvisoryID': 'VMSA-2011-0013.3',
#   'Synopsis': 'VMware third party component updates for VMware vCenter Server, vCenter Update Manager, ESXi and ESX'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2011-0012.html',
#   'AdvisoryID': 'VMSA-2011-0012.3',
#   'Synopsis': 'VMware ESXi and ESX updates to third party libraries and ESX Service Console'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2011-0011.html',
#   'AdvisoryID': 'VMSA-2011-0011',
#   'Synopsis': 'Hosted product updates address a remote code execution vulnerability in the way UDF file systems are handled'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2011-0010.html',
#   'AdvisoryID': 'VMSA-2011-0010.3',
#   'Synopsis': 'VMware ESX third party updates for Service Console packages glibc and dhcp'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2011-0009.html',
#   'AdvisoryID': 'VMSA-2011-0009.3',
#   'Synopsis': 'VMware hosted product updates, ESX patches and VI Client update resolve multiple security issue'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2011-0008.html',
#   'AdvisoryID': 'VMSA-2011-0008',
#   'Synopsis': 'VMware vCenter Server and vSphere Client security vulnerabilities'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2011-0007.html',
#   'AdvisoryID': 'VMSA-2011-0007',
#   'Synopsis': 'VMware ESXi and ESX Denial of Service and third party updates for Likewise components and ESX Service Console'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2011-0006.html',
#   'AdvisoryID': 'VMSA-2011-0006.1',
#   'Synopsis': 'VMware vmrun utility local privilege escalation'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2011-0005.html',
#   'AdvisoryID': 'VMSA-2011-0005.3',
#   'Synopsis': 'VMware vCenter Orchestrator and Alive Enterprise remote code execution vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2011-0004.html',
#   'AdvisoryID': 'VMSA-2011-0004.3',
#   'Synopsis': 'VMware ESX/ESXi SLPD denial of service vulnerability and ESX third party updates for Service Console packages bind, pam, and rpm.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2011-00031.html',
#   'AdvisoryID': 'VMSA-2011-0003.2',
#   'Synopsis': 'Cisco Nexus 1000V VEM updates address denial of service in VMware ESX/ESXi'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2011-0002.html',
#   'AdvisoryID': 'VMSA-2011-0002',
#   'Synopsis': 'Cisco Nexus 1000V VEM updates address denial of service in VMware ESX/ESXi'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2011-0001.html',
#   'AdvisoryID': 'VMSA-2011-0001.3',
#   'Synopsis': 'VMware ESX third party updates for Service Console packages glibc, sudo, and openldap'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2010-0020.html',
#   'AdvisoryID': 'VMSA-2010-0020.1',
#   'Synopsis': 'VMware ESXi 4.1 Update Installer SFCB Authentication Flaw'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2010-0019.html',
#   'AdvisoryID': 'VMSA-2010-0019.3',
#   'Synopsis': 'VMware ESX third party updates for Service Console'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2010-0018.html',
#   'AdvisoryID': 'VMSA-2010-0018',
#   'Synopsis': 'VMware hosted products and ESX patches resolve multiple security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2010-0017.html',
#   'AdvisoryID': 'VMSA-2010-0017.1',
#   'Synopsis': 'VMware ESX third party update for Service Console kernel'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2010-0015.html',
#   'AdvisoryID': 'VMSA-2010-0015.1',
#   'Synopsis': 'VMware ESX third party updates for Service Console'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2010-0016.html',
#   'AdvisoryID': 'VMSA-2010-0016.1',
#   'Synopsis': 'VMware ESXi and ESX third party updates for Service Console and Likewise components'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2010-0014.html',
#   'AdvisoryID': 'VMSA-2010-0014.1',
#   'Synopsis': 'VMware Workstation, Player, and ACE address several security issues.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2010-0013.html',
#   'AdvisoryID': 'VMSA-2010-0013.3',
#   'Synopsis': 'VMware ESX third party updates for Service Console'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2010-0012.html',
#   'AdvisoryID': 'VMSA-2010-0012.2',
#   'Synopsis': 'VMware vCenter Update Manager fix for Jetty Web server addresses important security vulnerabilities'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2010-0011.html',
#   'AdvisoryID': 'VMSA-2010-0011',
#   'Synopsis': 'VMware Studio 2.1 addresses security vulnerabilities in virtual appliances created with Studio 2.0.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2010-0010.html',
#   'AdvisoryID': 'VMSA-2010-0010',
#   'Synopsis': 'ESX 3.5 third party update for Service Console kernel'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2010-0009.html',
#   'AdvisoryID': 'VMSA-2010-0009.2',
#   'Synopsis': 'ESXi utilities and ESX Service Console third party updates'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2010-0008.html',
#   'AdvisoryID': 'VMSA-2010-0008',
#   'Synopsis': 'VMware View 3.1.3 addresses an important cross-site scripting vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2010-0007.html',
#   'AdvisoryID': 'VMSA-2010-0007.1',
#   'Synopsis': 'VMware hosted products, vCenter Server and ESX patches resolve multiple security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2010-0006.html',
#   'AdvisoryID': 'VMSA-2010-0006.1',
#   'Synopsis': 'ESX Service Console updates for samba and acpid'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2010-0005.html',
#   'AdvisoryID': 'VMSA-2010-0005',
#   'Synopsis': 'VMware products address vulnerabilities in WebAccess '},
#  {'AdvisoryURL': '/security/advisories/VMSA-2010-0004.html',
#   'AdvisoryID': 'VMSA-2010-0004.5',
#   'Synopsis': 'ESX Service Console and vMA third party updates'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2010-0001.html',
#   'AdvisoryID': 'VMSA-2010-0001.1',
#   'Synopsis': 'ESX Service Console and vMA updates for nss and nspr'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2010-0003.html',
#   'AdvisoryID': 'VMSA-2010-0003.1',
#   'Synopsis': 'VMSA-2010-0003.1 ESX Service Console update for net-snmp'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2010-0002.html',
#   'AdvisoryID': 'VMSA-2010-0002.4',
#   'Synopsis': 'VMware vCenter update release addresses multiple security issues in Java JRE'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2009-0017.html',
#   'AdvisoryID': 'VMSA-2009-0017',
#   'Synopsis': 'VMware vCenter, ESX patch and vCenter Lab Manager releases address cross-site scripting issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2009-0016.html',
#   'AdvisoryID': 'VMSA-2009-0016.6',
#   'Synopsis': 'VMware vCenter and ESX update release and vMA patch release address multiple security issues in third party components'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2009-0015.html',
#   'AdvisoryID': 'VMSA-2009-0015',
#   'Synopsis': 'VMware hosted products and ESX patches resolve two security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2009-0014.html',
#   'AdvisoryID': 'VMSA-2009-0014.3',
#   'Synopsis': 'VMware ESX patches for DHCP, Service Console kernel, and JRE resolve multiple security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2009-0013.html',
#   'AdvisoryID': 'VMSA-2009-0013',
#   'Synopsis': 'VMware Fusion resolves two security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2008-0015.html',
#   'AdvisoryID': 'VMSA-2008-0015',
#   'Synopsis': 'Updated ESXi and ESX 3.5 packages address critical security issue in openwsman'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2009-0012.html',
#   'AdvisoryID': 'VMSA-2009-0012',
#   'Synopsis': 'VMware Movie Decoder, VMware Workstation, VMware Player, and VMware ACE resolve security issues.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2009-0011.html',
#   'AdvisoryID': 'VMSA-2009-0011',
#   'Synopsis': 'VMware Studio 2.1 addresses security vulnerabilities in virtual appliances created with Studio 2.0'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2009-0010.html',
#   'AdvisoryID': 'VMSA-2009-0010.1',
#   'Synopsis': 'VMware Hosted products update libpng and Apache HTTP Server'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2009-0009.html',
#   'AdvisoryID': 'VMSA-2009-0009',
#   'Synopsis': 'ESX Service Console updates for udev, sudo, and curl'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2009-0008.html',
#   'AdvisoryID': 'VMSA-2009-0008.2',
#   'Synopsis': 'ESX Service Console update for krb5'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2009-0007.html',
#   'AdvisoryID': 'VMSA-2009-0007',
#   'Synopsis': 'VMware Hosted products and ESX and ESXi patches resolve security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2009-0006.html',
#   'AdvisoryID': 'VMSA-2009-0006',
#   'Synopsis': 'VMware Hosted products and patches for ESX and ESXi resolve a critical security vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2009-0005.html',
#   'AdvisoryID': 'VMSA-2009-0005',
#   'Synopsis': 'VMware Hosted products, VI Client and patches for ESX and ESXi resolve multiple security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2009-0004.html',
#   'AdvisoryID': 'VMSA-2009-0004.3',
#   'Synopsis': 'ESX Service Console updates for openssl, bind, and vim'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2009-0002.html',
#   'AdvisoryID': 'VMSA-2009-0002.2',
#   'Synopsis': 'VirtualCenter Update 4 and ESX patch update Tomcat to version 5.5.27'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2009-0001.html',
#   'AdvisoryID': 'VMSA-2009-0001.1',
#   'Synopsis': 'ESX patches address an issue loading corrupt virtual disks and update Service Console packages'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2009-0003.html',
#   'AdvisoryID': 'VMSA-2009-0003',
#   'Synopsis': 'ESX 2.5.5 patch 12 updates service console packag ed'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2008-0012.html',
#   'AdvisoryID': 'VMSA-2008-0012',
#   'Synopsis': 'Updated VirtualCenter addresses User Account Disclosure Vulnerability'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2008-0019.html',
#   'AdvisoryID': 'VMSA-2008-0019.1',
#   'Synopsis': 'VMware Hosted products and patches for ESX and ESXi resolve a critical security issue and update bzip2'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2008-0018.html',
#   'AdvisoryID': 'VMSA-2008-0018',
#   'Synopsis': 'VMware Hosted products and patches for ESX and ESXi resolve two security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2008-0017.html',
#   'AdvisoryID': 'VMSA-2008-0017.2',
#   'Synopsis': 'Updated ESX packages for libxml2, ucd-snmp, libtiff'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2008-0016.html',
#   'AdvisoryID': 'VMSA-2008-0016.3',
#   'Synopsis': 'VMware Hosted products, VirtualCenter Update 3 and patches for ESX and ESXi resolve multiple security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2008-0014.html',
#   'AdvisoryID': 'VMSA-2008-0014.3',
#   'Synopsis': 'Updates to VMware Workstation, VMware Player, VMware ACE, VMware Server, VMware ESX, VMware VCB address information disclosure, privilege escalation and other security issues.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2008-0013.html',
#   'AdvisoryID': 'VMSA-2008-0013.4',
#   'Synopsis': 'Updated ESX packages for OpenSSL, net-snmp, perl'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2008-0011.html',
#   'AdvisoryID': 'VMSA-2008-0011.3',
#   'Synopsis': 'Updated ESX service console packages for Samba and vmnix'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2008-0010.html',
#   'AdvisoryID': 'VMSA-2008-0010.3',
#   'Synopsis': 'Updated Tomcat and Java JRE packages for VMware ESX 3.5 and VirtualCenter'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2008-0009.html',
#   'AdvisoryID': 'VMSA-2008-0009.2',
#   'Synopsis': 'Updates to VMware Workstation, VMware Player, VMware ACE, VMware Fusion, VMware Server, VMware VIX API, VMware ESX, VMware ESXi resolve critical security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2008-0008.html',
#   'AdvisoryID': 'VMSA-2008-0008',
#   'Synopsis': 'Updates to VMware Workstation, VMware Player, VMware ACE, VMware Fusion resolve critical security issues'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2008-0007.html',
#   'AdvisoryID': 'VMSA-2008-0007.2',
#   'Synopsis': 'Moderate Updated Service Console packages pcre, net-snmp, and OpenPegasus'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2008-0006.html',
#   'AdvisoryID': 'VMSA-2008-0006.1',
#   'Synopsis': 'Updated libxml2 service console package'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2008-0005.html',
#   'AdvisoryID': 'VMSA-2008-0005.1',
#   'Synopsis': "Several critical security vulnerabilities have been addressed in the newest releases of VMware's hosted product line "},
#  {'AdvisoryURL': '/security/advisories/VMSA-2008-0004.html',
#   'AdvisoryID': 'VMSA-2008-0004.1',
#   'Synopsis': 'Updated e2fsprogs service console package'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2008-0003.html',
#   'AdvisoryID': 'VMSA-2008-0003.1',
#   'Synopsis': 'Updated aacraid driver and Samba and Python service console updates '},
#  {'AdvisoryURL': '/security/advisories/VMSA-2008-0001.html',
#   'AdvisoryID': 'VMSA-2008-0001.1',
#   'Synopsis': 'Updated service console patches.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2008-0002.html',
#   'AdvisoryID': 'VMSA-2008-0002.1',
#   'Synopsis': 'Updated Tomcat and Java JRE packages for VirtualCenter 2.5, VirtualCenter 2.0.2, ESX 3.5, ESX 3.0.2, and ESX 3.0.1. '},
#  {'AdvisoryURL': '/security/advisories/VMSA-2007-0006.html',
#   'AdvisoryID': 'VMSA-2007-0006',
#   'Synopsis': 'Updated versions of all supported hosted products and all ESX 2x products and patches for ESX 30x address critical security updates. Service Console security updates for samba, bind, krb5, vixie-cron, shadow-utils, openldap, pam, gcc, and gdb packages. '},
#  {'AdvisoryURL': '/security/advisories/VMSA-2007-0005.html',
#   'AdvisoryID': 'VMSA-2007-0005',
#   'Synopsis': 'Updated Service Console packages (XFree86, UP and SMP kernels, Kerberos libraries) resolve security issues.'},
#  {'AdvisoryURL': '/security/advisories/VMSA-2011-0003.html',
#   'AdvisoryID': 'VMSA-2011-0003.2',
#   'Synopsis': 'Third party component updates for VMware vCenter Server, vCenter Update Manager, ESXi and ESX'},
#  {'CVE': 'CVE-2020-3952',
#   'IssueDate': '2020-04-09',
#   'UpdatedOn': '2020-04-16',
#   'Severity': 'critical',
#   'AdvisoryURL': '/security/advisories/VMSA-2020-00061.html',
#   'AdvisoryID': 'VMSA-2020-0006.1',
#   'Synopsis': 'VMware vCenter Server updates address sensitive information disclosure vulnerability in the VMware Directory Service (vmdir) (CVE-2020-3952)',
#   'CVSSv3Range': '10.0'}]
